# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("healthcare_data_120_rows.csv")

sns.barplot(x='Age_Group', y='Readmitted', data=df)
plt.title("Readmission Rate by Age Group")
plt.show()
